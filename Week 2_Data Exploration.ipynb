# %%
import geopandas as gpd

# %%
city_activity = gpd.read_file('../../data/CAFR__City_Activities_2018.csv')

# %%
type(city_activity)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
city_activity.head()
# Out:
#    Year Crimes Reported Animals Adopted Animals Euthanized  \
# 0  2018          130804           34811               7015
# 1  2017          129692           32920               8425
# 2  2016          124623           31100              10931
# 3  2015          111690           32826              14083
# 4  2014          101228           32910              15028
#
#   Fatal And Injury Traffic Accidents Citations Written  \
# 0                              25387           2237086
# 1                              25259           2302206
# 2                              24399           2395778
# 3                              24974           2489390
# 4                              21026           2659718
#
#   Fixed Transit Route Passenger Trips Signs Maintained/Replaced  \
# 0                            18127858                     28115
# 1                            19465764                     46189
# 2                            23590779                     52422
# ...

# %%
city_activity.tail()
# Out:
#    Year Crimes Reported Animals Adopted Animals Euthanized  \
# 5  2013          103856           32440              17063
# 6  2012          104604           30414              23955
# 7  2011          106827           29525              24632
# 8  2010          110827           26952              25298
# 9  2009          115000           28154              24742
#
#   Fatal And Injury Traffic Accidents Citations Written  \
# 5                              20996           2654910
# 6                              21216           2522302
# 7                              18448           2461529
# 8                              20408           2587925
# 9                              26000           2784351
#
#   Fixed Transit Route Passenger Trips Signs Maintained/Replaced  \
# 5                            26154372                     43728
# 6                            23736486                     66556
# 7                            27356994                     63019
# ...

# %%
city_activity.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 30 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Year                                      10 non-null     object
#  1   Crimes Reported                           10 non-null     object
#  2   Animals Adopted                           10 non-null     object
#  3   Animals Euthanized                        10 non-null     object
#  4   Fatal And Injury Traffic Accidents        10 non-null     object
#  5   Citations Written                         10 non-null     object
#  6   Fixed Transit Route Passenger Trips       10 non-null     object
#  7   Signs Maintained/Replaced                 10 non-null     object
#  8   Congregate Meals Served                   10 non-null     object
#  9   Affordable Units Monitored                10 non-null     object
# ...

# %%
city_activity.shape
# Out:
# (10, 30)

# %%
city_activity.dtypes
# Out:
# Year                                          object
# Crimes Reported                               object
# Animals Adopted                               object
# Animals Euthanized                            object
# Fatal And Injury Traffic Accidents            object
# Citations Written                             object
# Fixed Transit Route Passenger Trips           object
# Signs Maintained/Replaced                     object
# Congregate Meals Served                       object
# Affordable Units Monitored                    object
# Tenant Complaints Processed                   object
# Graffiti Eradicated                           object
# Streetligths Converted To Led Citywide        object
# Small Asphalt Repairs                         object
# Observatory Attendance                        object
# Municipal Sports Team  Participants           object
# Delegates Attending Citywide Conventions      object
# Art Class Enrollment                          object
# ...

# %%
city_activity.columns.to_list()
# Out:
# ['Year',
#  'Crimes Reported',
#  'Animals Adopted',
#  'Animals Euthanized',
#  'Fatal And Injury Traffic Accidents',
#  'Citations Written',
#  'Fixed Transit Route Passenger Trips',
#  'Signs Maintained/Replaced',
#  'Congregate Meals Served',
#  'Affordable Units Monitored',
#  'Tenant Complaints Processed',
#  'Graffiti Eradicated',
#  'Streetligths Converted To Led Citywide',
#  'Small Asphalt Repairs',
#  'Observatory Attendance',
#  'Municipal Sports Team  Participants',
#  'Delegates Attending Citywide Conventions',
#  'Art Class Enrollment',
#  'Registered Borrowers',
#  'Recreational Swim Attendance',
#  'Recyclables Collected',
#  'Catch Basins Cleaned',
#  'Miles Of Sewers Cleaned',
#  'Airport Passengers',
#  'Air Cargo',
#  'Inbound Tonnage',
#  'Outbound Tonnage',
#  'Vessel Arrivals',
#  'Cruise Passengers',
#  'geometry']

# %%
city_activity.head()
# Out:
#    Year Crimes Reported Animals Adopted Animals Euthanized  \
# 0  2018          130804           34811               7015
# 1  2017          129692           32920               8425
# 2  2016          124623           31100              10931
# 3  2015          111690           32826              14083
# 4  2014          101228           32910              15028
#
#   Fatal And Injury Traffic Accidents Citations Written  \
# 0                              25387           2237086
# 1                              25259           2302206
# 2                              24399           2395778
# 3                              24974           2489390
# 4                              21026           2659718
#
#   Fixed Transit Route Passenger Trips Signs Maintained/Replaced  \
# 0                            18127858                     28115
# 1                            19465764                     46189
# 2                            23590779                     52422
# ...

# %%
desired_columns= ['Year', 'Crimes Reported', 'Citations Written', 'Airport Passengers']

# %%
city_activity[desired_columns]
# Out:
#    Year Crimes Reported Citations Written Airport Passengers
# 0  2018          130804           2237086               86.6
# 1  2017          129692           2302206               84.3
# 2  2016          124623           2395778                 82
# 3  2015          111690           2489390               76.2
# 4  2014          101228           2659718               72.8
# 5  2013          103856           2654910                 69
# 6  2012          104604           2522302                 67
# 7  2011          106827           2461529                 65
# 8  2010          110827           2587925                 63
# 9  2009          115000           2784351                 62

# %%
city_activity_trimmed=city_activity[desired_columns]

# %%
city_activity_trimmed.head()
# Out:
#    Year Crimes Reported Citations Written Airport Passengers
# 0  2018          130804           2237086               86.6
# 1  2017          129692           2302206               84.3
# 2  2016          124623           2395778                 82
# 3  2015          111690           2489390               76.2
# 4  2014          101228           2659718               72.8

# %%
city_activity_trimmed.info
# Out:
# <bound method DataFrame.info of    Year Crimes Reported Citations Written Airport Passengers
# 0  2018          130804           2237086               86.6
# 1  2017          129692           2302206               84.3
# 2  2016          124623           2395778                 82
# 3  2015          111690           2489390               76.2
# 4  2014          101228           2659718               72.8
# 5  2013          103856           2654910                 69
# 6  2012          104604           2522302                 67
# 7  2011          106827           2461529                 65
# 8  2010          110827           2587925                 63
# 9  2009          115000           2784351                 62>
